# %%
# import numpy
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot
import matplotlib.pyplot as plt

# import seaborn
import seaborn as sns

# to suppress the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load the csv file
df = pd.read_csv('CarPrice_Assignment.csv')

# display the first five observations
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std        NaN
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#checking null values
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          5
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          4
# peakrpm             4
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio            object
# stroke               object
# compressionratio    float64
# horsepower          float64
# peakrpm             float64
# citympg               int64
# highwaympg            int64
# price                object
# dtype: object

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize  compressionratio  horsepower      peakrpm  \
# count   205.000000  205.000000        205.000000  201.000000   201.000000
# mean   2555.565854  126.907317         10.142537  103.567164  5124.378109
# ...

# %%
df.skew()
# Out:
# car_ID              0.000000
# symboling           0.211072
# wheelbase           1.050214
# carlength           0.155954
# carwidth            0.904003
# carheight           0.063123
# curbweight          0.681398
# enginesize          1.947655
# compressionratio    2.610862
# horsepower          1.455314
# peakrpm             0.107451
# citympg             0.663704
# highwaympg          0.539997
# dtype: float64

# %%
df.kurt()
# Out:
# car_ID             -1.200000
# symboling          -0.676271
# wheelbase           1.017039
# carlength          -0.082895
# carwidth            0.702764
# carheight          -0.443812
# curbweight         -0.042854
# enginesize          5.305682
# compressionratio    5.233054
# horsepower          2.942532
# peakrpm             0.117623
# citympg             0.578648
# highwaympg          0.440070
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        200 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#Eda
#Univariate--single variable
#Bivariarte
#Multivariate

# %%
sns.histplot(df.wheelbase)
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='Count'>

# %%
#boxplot of peakrpm 
sns.boxplot(df.peakrpm)
# Out:
# <AxesSubplot:xlabel='peakrpm'>

# %%
#Bivariate
sns.scatterplot(x=df['carlength'],y=df['carwidth'])
# Out:
# <AxesSubplot:xlabel='carlength', ylabel='carwidth'>

# %%
#Multivariate 
sns.pairplot(df)

# %%
corr=df.corr()
corr
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower        0.007019   0.083040   0.348445   0.546176  0.639110
# peakrpm          -0.208293   0.272390  -0.381839  -0.312250 -0.266854
# citympg           0.015940  -0.035823  -0.470414  -0.670909 -0.642704
# ...

# %%
#day2
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio            object
# stroke               object
# compressionratio    float64
# horsepower          float64
# peakrpm             float64
# citympg               int64
# highwaympg            int64
# price                object
# dtype: object

# %%
df['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
#missing values 
#doornumber,horsepower,peakrpm
df['doornumber'].unique
# Out:
# <bound method Series.unique of 0       two
# 1       two
# 2       two
# 3      four
# 4       NaN
#        ...
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: doornumber, Length: 205, dtype: object>

# %%
#handling object--categorical column 
df['doornumber'].mode()
# Out:
# 0    four
# dtype: object

# %%
df['doornumber'].value_counts()
# Out:
# four    118
# two      87
# Name: doornumber, dtype: int64

# %%
df['doornumber'].replace(np.nan,'four',inplace=True)

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          4
# peakrpm             4
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#Non Standard missing values

# %%
df['boreratio'].value_counts()
# Out:
# 3.62    23
# 3.19    19
# 3.15    14
# 3.03    12
# 2.97    11
# 3.46     9
# 3.43     8
# 3.31     8
# 3.78     8
# 2.91     7
# 3.27     7
# 3.58     6
# 3.33     6
# 3.54     6
# 3.05     6
# 3.39     6
# 3.7      5
# 3.01     5
# ?        4
# 3.35     4
# 3.59     3
# 3.17     3
# 3.74     3
# 3.24     2
# 3.94     2
# 3.5      2
# 3.47     2
# 3.8      2
# 3.63     2
# 3.34     1
# 2.68     1
# 2.99     1
# 3.61     1
# 3.6      1
# 2.92     1
# 2.54     1
# 3.13     1
# 3.76     1
# 3.08     1
# Name: boreratio, dtype: int64

# %%
# replace ? with np.nan
df.replace('?',np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           4
# stroke              3
# compressionratio    0
# horsepower          4
# peakrpm             4
# citympg             0
# highwaympg          0
# price               2
# dtype: int64

# %%
#boreratio,stroke,horsepower,peakrpm,price
#Create a markdown cell and write the column names with missing values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df[['horsepower','peakrpm','stroke','boreratio','price']]=df[['horsepower','peakrpm','stroke','boreratio','price']].astype("float")

# %% [markdown]
# df[['horsepower']]=df[['horsepower']].astype("float")

# %%
avgbore=df['boreratio'].astype('float').mean()

# %%
avgbore
# Out:
# 3.3341293532338323

# %%
df['boreratio'].replace(np.nan,avgbore,inplace=True)

# %%
random value ---standize form --random--np.nan ---missing values

# %%
--Task stroke,horsepower,peakrpm,price

# %%
avgstroke=df['stroke'].mean()
df['stroke'].replace(np.nan,avgstroke,inplace=True)

# %% [markdown]
# #horsepower,peakrpm,price
# Missing values
#
# drop data                                Replace data
#
# drop whole row ,drop whole column         number--mean,median       categorical/object ---frequency (mode)

# %%
#
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          4
# peakrpm             4
# citympg             0
# highwaympg          0
# price               2
# dtype: int64

# %%
avg=df['horsepower'].mean()
df['horsepower'].replace(np.nan,avg,inplace=True)

# %%
avg=df['price'].mean()
df['price'].replace(np.nan,avg,inplace=True)

# %%
avg=df['peakrpm'].mean()
df['peakrpm'].replace(np.nan,avg,inplace=True)

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
Handle non numeric data 
numbers--
predict-- education vs salary 

column-education ---graduate,PG,PHD
#1.Dummy encoding,N-1 encoding
2.One Hot encoding 
3.Label encoding  
4.Ordinal encoding

# %%
#Label encoding 
-Gas --Diesel 
--Nominal categorical 
Gender --male--female--Not specified

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df['encoded_fueltype']=labelencoder.fit_transform(df.fueltype)

# %%
df['encoded_fueltype']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 200    1
# 201    1
# 202    1
# 203    0
# 204    1
# Name: encoded_fueltype, Length: 205, dtype: int32

# %%
#Ordinal encoding 
pip install category_encoders

Degree -High school Diploma Bachelors

# %%
import category_encoders as ce
train=pd.DataFrame({'Degree':['Highschool','Diploma','Bachelors']})

# %%
encoder=ce.OrdinalEncoder(cols=['Degree'],mapping=[{'col':'Degree','mapping':{'Highschool':1,'Diploma':2,'Bachelors':3}}])

# %%
encoded_train=encoder.fit_transform(train)
encoded_train
# Out:
#    Degree
# 0       1
# 1       2
# 2       3

# %%
import category_encoders as ce
train=pd.DataFrame({'Degree':['Highschool','Diploma','Bachelors']})
encoder=ce.OrdinalEncoder(cols=['Degree'],mapping=[{'col':'Degree','mapping':{'Highschool':1,'Diploma':2,'Bachelors':3}}])
encoded_train=encoder.fit_transform(train)
encoded_train
# Out:
#    Degree
# 0       1
# 1       2
# 2       3

# %%
# Encoding 
One Hot Encoding  drawback -- multicollinearity 
Label encoding -- 1,2,3 hierarchy better One Hot encoding technique --N-1 columns 
Ordinal encoding 

Comparision Between encoding techniques
Trick N,N-1 columns 
Dummy --columns colinear outcome 1 variable can be predicted with other remaining variables
--Trap multicollinearity --dependency between independent features/columns --Linear Regression/Logistic Regression 
--check multicollinearity
--Vif Variation Inflation Factor 
Vif=1  very less multicolliearity
Vif <5 moderate
vif >5 high

# %%
we will use One Hot encoding 
1.categorical feature is not ordinal 
2.less 
Label Encoding -- Ordinal data 
E.g Junior Kg,Senior Kg ,High school

# %%
Data Analysis --Dataengineering --Datascientist
